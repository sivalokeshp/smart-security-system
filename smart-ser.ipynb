# %%
from IPython.display import clear_output,Video
import keras
import numpy as np 
import cv2

# %%
scvd_train_dir = '/kaggle/input/smartcity-cctv-violence-detection-dataset-scvd/SCVD/SCVD_converted_sec_split/Train'
scvd_test_dir = '/kaggle/input/smartcity-cctv-violence-detection-dataset-scvd/SCVD/SCVD_converted_sec_split/Test'
scvd_classes = ['Normal', 'Violence','Weaponized']

# %%
# Define the base directory and categories
base_dir = '/kaggle/input/smartcity-cctv-violence-detection-dataset-scvd/SCVD/SCVD_converted_sec_split/Train'
categories = ['Normal', 'Violence', 'Weaponized']

# %%
import os

# Function to count videos in each category
def count_videos(base_dir, categories):
    video_count = {}
    
    for category in categories:
        category_path = os.path.join(base_dir, category)
        
        if not os.path.exists(category_path):
            print(f"Directory for category '{category}' not found.")
            video_count[category] = 0
            continue
        
        # List all video files in the category directory
        video_files = [f for f in os.listdir(category_path) if f.endswith(('.mp4', '.avi', '.mkv'))]
        video_count[category] = len(video_files)
    
    return video_count

# Call the function and print the counts
video_counts = count_videos(base_dir, categories)

print("Video counts per category:")
for category, count in video_counts.items():
    print(f"{category}: {count} videos")
# Out:
# Video counts per category:
# Normal: 872 videos
# Violence: 970 videos
# Weaponized: 832 videos

# %%
IMG_SIZE = 224
BATCH_SIZE = 64
EPOCHS = 50

MAX_SEQ_LENGTH = 20
NUM_FEATURES = 2048

# %%
# Define the label mapping
label_mapping = {"Normal": 0, "Violence": 1, "Weaponized": 2}

# %%
IMG_SIZE = 224
BATCH_SIZE = 64
EPOCHS = 50

MAX_SEQ_LENGTH = 20
NUM_FEATURES = 2048

# Define the label mapping
label_mapping = {"Normal": 0, "Violence": 1, "Weaponized": 2}

def crop_center_square(frame):
    y, x = frame.shape[0:2]
    min_dim = min(y, x)
    start_x = (x // 2) - (min_dim // 2)
    start_y = (y // 2) - (min_dim // 2)
    return frame[start_y : start_y + min_dim, start_x : start_x + min_dim]


def load_video(path, max_frames=0, resize=(IMG_SIZE, IMG_SIZE)):
    cap = cv2.VideoCapture(path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = crop_center_square(frame)
            frame = cv2.resize(frame, resize)
            frame = frame[:, :, [2, 1, 0]]
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
    return np.array(frames)

# %%
IMG_SIZE = 224
BATCH_SIZE = 64
EPOCHS = 50

MAX_SEQ_LENGTH = 20
NUM_FEATURES = 2048

# Define the label mapping
label_mapping = {"Normal": 0, "Violence": 1, "Weaponized": 2}

def crop_center_square(frame):
    y, x = frame.shape[0:2]
    min_dim = min(y, x)
    start_x = (x // 2) - (min_dim // 2)
    start_y = (y // 2) - (min_dim // 2)
    return frame[start_y : start_y + min_dim, start_x : start_x + min_dim]


def load_video(path, max_frames=0, resize=(IMG_SIZE, IMG_SIZE)):
    cap = cv2.VideoCapture(path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = crop_center_square(frame)
            frame = cv2.resize(frame, resize)
            frame = frame[:, :, [2, 1, 0]]
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
    return np.array(frames)

def build_feature_extractor():
    feature_extractor = keras.applications.InceptionV3(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.inception_v3.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return keras.Model(inputs, outputs, name="feature_extractor")


feature_extractor = build_feature_extractor()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
def prepare_all_videos(df, root_dir):
    num_samples = len(df)
    video_paths = df["original_path"].values  # Use the 'original_path' column
    labels = df["label"].map(label_mapping).values  # Assuming label_mapping is defined

    # Initialize placeholders for masks and features
    frame_masks = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH), dtype="bool")
    frame_features = np.zeros(
        shape=(num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
    )

    # For each video
    for idx, path in enumerate(video_paths):
        # Gather all its frames and add a batch dimension
        frames = load_video(path)  # Use the full path directly
        frames = frames[None, ...]

        # Initialize placeholders for the current video's masks and features
        temp_frame_mask = np.zeros(shape=(1, MAX_SEQ_LENGTH,), dtype="bool")
        temp_frame_features = np.zeros(
            shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
        )

        # Extract features from the frames of the current video
        for i, batch in enumerate(frames):
            video_length = batch.shape[0]
            length = min(MAX_SEQ_LENGTH, video_length)
            for j in range(length):
                temp_frame_features[i, j, :] = feature_extractor.predict(
                    batch[None, j, :]
                )
            temp_frame_mask[i, :length] = 1  # 1 = not masked, 0 = masked

        # Store features and masks for the current video
        frame_features[idx,] = temp_frame_features.squeeze()
        frame_masks[idx,] = temp_frame_mask.squeeze()

    return (frame_features, frame_masks), labels

# %%
import os
import pandas as pd

# Base directory for the dataset
base_dir = '/kaggle/input/smartcity-cctv-violence-detection-dataset-scvd/SCVD/SCVD_converted_sec_split/Train'

# Define the class labels
categories = ['Normal', 'Violence', 'Weaponized']

# Initialize a list to store metadata
metadata = []

# Traverse through each category
for category in categories:
    category_path = os.path.join(base_dir, category)
    if not os.path.exists(category_path):
        print(f"Category directory '{category}' not found!")
        continue

    # List all video files in the category directory
    video_files = [f for f in os.listdir(category_path) if f.endswith(('.mp4', '.avi', '.mkv'))]
    for video_file in video_files:
        # Create full path to the video
        video_path = os.path.join(category_path, video_file)
        # Append metadata
        metadata.append({'original_path': video_path, 'label': category})

# Create a DataFrame from the metadata
train_sample_metadata = pd.DataFrame(metadata)

# Display the first few rows
print("Sample of train_sample_metadata:")
print(train_sample_metadata.head())

# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

Train_set, Test_set = train_test_split(
    train_sample_metadata,
    test_size=0.1,
    random_state=42,
    stratify=train_sample_metadata['label']
)

print("Train and Test set shapes:")
print(Train_set.shape, Test_set.shape)
# Out:
# Sample of train_sample_metadata:
#                                        original_path   label
# 0  /kaggle/input/smartcity-cctv-violence-detectio...  Normal
# 1  /kaggle/input/smartcity-cctv-violence-detectio...  Normal
# 2  /kaggle/input/smartcity-cctv-violence-detectio...  Normal
# 3  /kaggle/input/smartcity-cctv-violence-detectio...  Normal
# 4  /kaggle/input/smartcity-cctv-violence-detectio...  Normal
# Train and Test set shapes:
# (2406, 2) (268, 2)

# %%
train_data, train_labels = prepare_all_videos(Train_set, "train")
test_data, test_labels = prepare_all_videos(Test_set, "test")

print(f"Frame features in train set: {train_data[0].shape}")
print(f"Frame masks in train set: {train_data[1].shape}")

# %%
    
print(f"Frame features in train set: {train_data[0].shape}")
print(f"Frame masks in train set: {train_data[1].shape}")
# Out:
# Frame features in train set: (2406, 20, 2048)
# Frame masks in train set: (2406, 20)

# %%
frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")

# Refer to the following tutorial to understand the significance of using `mask`:
# https://keras.io/api/layers/recurrent_layers/gru/
x = keras.layers.GRU(16, return_sequences=True)(
    frame_features_input, mask=mask_input
)
x = keras.layers.GRU(8)(x)
x = keras.layers.Dropout(0.4)(x)
x = keras.layers.Dense(8, activation="relu")(x)
output = keras.layers.Dense(3, activation="softmax")(x)

model = keras.Model([frame_features_input, mask_input], output)

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 20, 2048)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_5       │ (None, 20)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_2 (GRU)         │ (None, 20, 16)    │     99,168 │ input_layer_4[0]… │
# │                     │                   │            │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_3 (GRU)         │ (None, 8)         │        624 │ gru_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 8)         │          0 │ gru_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 8)         │         72 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 3)         │         27 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 99,891 (390.20 KB)
#  Trainable params: 99,891 (390.20 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import to_categorical

# Convert labels to one-hot encoding
train_labels_one_hot = to_categorical(train_labels, num_classes=3)
test_labels_one_hot = to_categorical(test_labels, num_classes=3)

# Ensure model is compiled only once, before calling fit
model = keras.Model([frame_features_input, mask_input], output)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model
checkpoint = keras.callbacks.ModelCheckpoint('./best_weights.weights.h5', 
                                              save_weights_only=True, 
                                              save_best_only=True)

history = model.fit(
    [train_data[0], train_data[1]],  # Frame features and masks
    train_labels_one_hot,  # One-hot encoded labels
    validation_data=([test_data[0], test_data[1]], test_labels_one_hot),  # One-hot encoded validation labels
    callbacks=[checkpoint],
    epochs=200,
    batch_size=8
)
# Out:
# Epoch 1/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.5957 - loss: 0.8041 - val_accuracy: 0.5261 - val_loss: 0.9334
# Epoch 2/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5907 - loss: 0.7907 - val_accuracy: 0.5187 - val_loss: 0.8993
# Epoch 3/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5883 - loss: 0.7859 - val_accuracy: 0.5299 - val_loss: 0.8955
# Epoch 4/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5568 - loss: 0.8040 - val_accuracy: 0.5336 - val_loss: 0.8694
# Epoch 5/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5892 - loss: 0.7793 - val_accuracy: 0.5224 - val_loss: 0.8753
# Epoch 6/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5968 - loss: 0.7613 - val_accuracy: 0.5261 - val_loss: 0.8852
# Epoch 7/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5855 - loss: 0.7582 - val_accuracy: 0.5634 - val_loss: 0.8636
# Epoch 8/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5897 - loss: 0.7420 - val_accuracy: 0.5299 - val_loss: 0.8662
# Epoch 9/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.
200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9704 - loss: 0.1250 - val_accuracy: 0.8582 - val_loss: 0.5979
# Epoch 196/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9717 - loss: 0.1219 - val_accuracy: 0.8769 - val_loss: 0.6026
# Epoch 197/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9617 - loss: 0.1560 - val_accuracy: 0.8657 - val_loss: 0.6729
# Epoch 198/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9593 - loss: 0.1590 - val_accuracy: 0.8694 - val_loss: 0.4654
# Epoch 199/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9700 - loss: 0.1237 - val_accuracy: 0.8731 - val_loss: 0.5084
# Epoch 200/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9709 - loss: 0.1236 - val_accuracy: 0.8806 - val_loss: 0.5408

# %%
import matplotlib.pyplot as plt

# Extract the history of accuracy and loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Plot training & validation loss values
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy Plot
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Train Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Predict the labels for the test data
y_pred = model.predict([test_data[0], test_data[1]])
y_pred_classes = np.argmax(y_pred, axis=1)  # Get the index of the max probability for each prediction
y_true = np.argmax(test_labels_one_hot, axis=1)  # Get the true labels from one-hot encoding

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Plot Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Normal', 'Violence', 'Weaponized'], 
            yticklabels=['Normal', 'Violence', 'Weaponized'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Classification Report
cr = classification_report(y_true, y_pred_classes, target_names=['Normal', 'Violence', 'Weaponized'])
print("Classification Report:\n", cr)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.94      0.85      0.89        88
#     Violence       0.80      0.93      0.86        97
#   Weaponized       0.93      0.86      0.89        83
#
#     accuracy                           0.88       268
#    macro avg       0.89      0.88      0.88       268
# weighted avg       0.89      0.88      0.88       268

# %%
# Save the entire model (architecture, weights, optimizer)
model.save('GRU.h5')

# %%
from keras.models import load_model
model = load_model('GRU.h5')

# %%
pip list
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Package                                  Version            Editable project location
# ---------------------------------------- ------------------ -------------------------
# absl-py                                  1.4.0
# accelerate                               1.1.1
# aiobotocore                              2.15.2
# aiofiles                                 22.1.0
# aiohttp                                  3.9.5
# aioitertools                             0.12.0
# aiosignal                                1.3.1
# aiosqlite                                0.20.0
# albucore                                 0.0.20
# albumentations                           1.4.21
# alembic                                  1.14.0
# altair                                   5.5.0
# annotated-types                          0.7.0
# annoy                                    1.17.3
# ansicolors                               1.1.8
# anyio                                    4.4.0
# apache-beam                              2.46.0
# appdirs                                  1.4.4
# archspec                                 0.2.3
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# array_record                             0.5.1
# arrow                                    1.3.0
# arviz                                    0.20.0
# astroid                                  3.3.5
# asttokens                                2.4.1
# astunparse                               1.6.3
# async-lru                                2.0.4
# async-timeout                            4.0.3
# atpublic                                 4.1.0
# attrs                                    23.2.0
# audioread                                3.0.1
# autopep8                                 2.0.4
# Babel                                    2.15.0
# backports.tarfile                        1.2.0
# bayesian-optimization                    2.0.0
# beatrix_jupyterlab                       2024.66.154055
# beautifulsoup4                           4.12.3
# bidict                                   0.23.1
# bigframes                                0.22.0
# bleach                                   6.1.0
# blessed                                  1.20.0
# blinker                                  1.9.0
# blis                                     1.0.1
# blosc2                                   2.7.1
# bokeh                                    3.6.1
# boltons                                  24.0.0
# Boruta                                   0.4.3
# boto3                                    1.26.100
# botocore                                 1.35.36
# bq_helper                                0.4.1              /root/src/BigQuery_Helper
# bqplot                                   0.12.43
# branca                                   0.8.0
# Brotli                                   1.1.0
# brotlipy                                 0.7.0
# cached-property                          1.5.2
# cachetools                               4.2.4
# Cartopy                                  0.24.0
# catalogue                                2.0.10
# catboost                                 1.2.7
# category-encoders                        2.6.4
# certifi                                  2024.6.2
# cesium                                   0.12.3
# cffi                                     1.16.0
# charset-normalizer                       3.3.2
# Chessnut                                 0.3.1
# chex                                     0.1.86
# click                                    8.1.7
# click-plugins                            1.1.1
# cligj                                    0.7.2
# cloud-tpu-client                         0.10
# cloud-tpu-profiler                       2.4.0
# cloudpathlib                             0.20.0
# cloudpickle                              3.1.0
# cmdstanpy                                1.2.4
# colorama                                 0.4.6
# colorcet                                 3.1.0
# colorful                                 0.5.6
# colorlog                                 6.9.0
# colorlover                               0.3.0
# comm                                     0.2.2
# conda                                    24.5.0
# conda-content-trust                      0+unknown
# conda-libmamba-solver                    24.1.0
# conda-package-handling                   2.3.0
# conda_package_streaming                  0.10.0
# confection                               0.1.4
# contourpy                                1.2.1
# crcmod                                   1.7
# cryptography                             42.0.8
# cuda-python                              12.6.2.post1
# cudf                                     24.10.1
# cufflinks                                0.17.3
# cuml                                     24.10.0
# cupy                                     13.3.0
# CVXcanon                                 0.1.2
# cycler                                   0.12.1
# cymem                                    2.0.10
# Cython                                   3.0.10
# cytoolz                                  1.0.0
# daal                                     2025.0.0
# dacite                                   1.8.1
# dask                                     2024.11.2
# dask-cuda                                24.10.0
# dask-cudf                                24.10.1
# dask-expr                                1.1.19
# dataclasses-json                         0.6.7
# dataproc_jupyter_plugin                  0.1.79
# datasets                                 3.1.0
# datashader                               0.16.3
# datatile                                 1.0.3
# db-dtypes                                1.2.0
# deap                                     1.4.1
# debugpy                                  1.8.1
# decorator                                5.1.1
# deepdiff                                 8.0.1
# defusedxml                               0.7.1
# Deprecated                               1.2.14
# dill                                     0.3.8
# dipy                                     1.9.0
# distlib                                  0.3.8
# distributed                              2024.9.0
# distributed-ucxx                         0.40.0
# distro                                   1.9.0
# dm-tree                                  0.1.8
# dnspython                                2.6.1
# docker                                   7.1.0
# docker-pycreds                           0.4.0
# docopt                                   0.6.2
# docstring_parser                         0.16
# docstring-to-markdown                    0.15
# earthengine-api                          1.4.1
# easyocr                                  1.7.2
# ecos                                     2.0.14
# eli5                                     0.13.0
# email_validator                          2.1.1
# emoji                                    2.14.0
# en_core_web_lg                           3.8.0
# en_core_web_sm                           3.8.0
# entrypoints                              0.4
# et_xmlfile                               2.0.0
# etils                                    1.7.0
# eval_type_backport                       0.2.0
# exceptiongroup                           1.2.0
# execnb                                   0.1.8
# executing                                2.0.1
# explainable-ai-sdk                       1.3.3
# Farama-Notifications                     0.0.4
# fastai                                   2.7.18
# fastapi                                  0.111.0
# fastapi-cli                              0.0.4
# fastavro                                 1.9.4
# fastcore                                 1.7.20
# fastdownload                             0.0.7
# fasteners                                0.19
# fastjsonschema                           2.19.1
# fastprogress                             1.0.3
# fastrlock                                0.8.2
# fasttext                                 0.9.3
# featuretools                             1.31.0
# filelock                                 3.15.1
# fiona                                    1.9.6
# flake8                                   7.1.1
# Flask                                    3.1.0
# flatbuffers                              24.3.25
# flax                                     0.8.4
# folium                                   0.18.0
# fonttools                                4.53.0
# fqdn                                     1.5.1
# frozendict                               2.4.4
# frozenlist                               1.4.1
# fsspec                                   2024.6.0
# funcy                                    2.0
# fury                                     0.11.0
# future                                   1.0.0
# fuzzywuzzy                               0.18.0
# gast                                     0.5.4
# gatspy                                   0.3
# gcsfs                                    2024.9.0.post1
# gensim                                   4.3.3
# geographiclib                            2.0
# geojson                                  3.1.0
# geopandas                                0.14.4
# geopy                                    2.4.1
# ghapi                                    1.0.6
# gitdb                                    4.0.11
# GitPython                                3.1.43
# google-ai-generativelanguage             0.6.10
# google-api-core                          2.11.1
# google-api-python-client                 2.154.0
# google-apitools                          0.5.31
# google-auth                              2.30.0
# google-auth-httplib2                     0.2.0
# google-auth-oauthlib                     1.2.0
# google-cloud-aiplatform                  0.6.0a1
# google-cloud-artifact-registry           1.11.3
# google-cloud-automl                      1.0.1
# google-cloud-bigquery                    2.34.4
# google-cloud-bigquery-connection         1.15.3
# google-cloud-bigtable                    1.7.3
# google-cloud-core                        2.4.1
# google-cloud-datastore                   1.15.5
# google-cloud-dlp                         3.18.0
# google-cloud-functions                   1.16.3
# google-cloud-iam                         2.15.0
# google-cloud-jupyter-config              0.0.10
# google-cloud-language                    2.15.1
# google-cloud-monitoring                  2.21.0
# google-cloud-pubsub                      2.21.3
# google-cloud-pubsublite                  1.10.0
# google-cloud-recommendations-ai          0.7.1
# google-cloud-resource-manager            1.12.3
# google-cloud-spanner                     3.47.0
# google-cloud-storage                     1.44.0
# google-cloud-translate                   3.12.1
# google-cloud-videointelligence           2.14.1
# google-cloud-vision                      2.8.0
# google-crc32c                            1.5.0
# google-generativeai                      0.8.3
# google-pasta                             0.2.0
# google-resumable-media                   2.7.1
# googleapis-common-protos                 1.63.1
# gpustat                                  1.0.0
# gpxpy                                    1.6.2
# graphviz                                 0.20.3
# greenlet                                 3.0.3
# grpc-google-iam-v1                       0.12.7
# grpc-interceptor                         0.15.4
# grpcio                                   1.62.2
# grpcio-status                            1.48.0
# gviz-api                                 1.10.0
# gym                                      0.26.2
# gym-notices                              0.0.8
# gymnasium                                0.29.0
# h11                                      0.14.0
# h2o                                      3.46.0.6
# h5netcdf                                 1.4.1
# h5py                                     3.11.0
# haversine                                2.8.1
# hdfs                                     2.7.3
# hep_ml                                   0.7.3
# holidays                                 0.61
# holoviews                                1.20.0
# html5lib                                 1.1
# htmlmin                                  0.1.12
# httpcore                                 1.0.5
# httplib2                                 0.21.0
# httptools                                0.6.1
# httpx                                    0.27.0
# huggingface-hub                          0.26.2
# humanize                                 4.9.0
# hyperopt                                 0.2.7
# ibis-framework                           7.1.0
# idna                                     3.7
# igraph                                   0.11.8
# ImageHash                                4.3.1
# imageio                                  2.34.1
# imbalanced-learn                         0.12.4
# imgaug                                   0.4.0
# immutabledict                            4.2.0
# importlib-metadata                       7.0.0
# importlib_resources                      6.4.0
# iniconfig                                2.0.0
# ipykernel                                6.29.4
# ipympl                                   0.7.0
# ipython                                  8.21.0
# ipython-genutils                         0.2.0
# ipython-sql                              0.5.0
# ipywidgets                               8.1.5
# isoduration                              20.11.0
# isort                                    5.13.2
# isoweek                                  1.3.3
# itsdangerous                             2.2.0
# Janome                                   0.5.0
# jaraco.classes                           3.4.0
# jaraco.context                           5.3.0
# jaraco.functools                         4.0.1
# jax                                      0.4.26
# jax-jumpy                                1.0.0
# jaxlib                                   0.4.26.dev20240620
# jedi                                     0.19.1
# jeepney                                  0.8.0
# jieba                                    0.42.1
# Jinja2                                   3.1.4
# jmespath                                 1.0.1
# joblib                                   1.4.2
# json5                                    0.9.25
# jsonpatch                                1.33
# jsonpointer                              2.4
# jsonschema                               4.22.0
# jsonschema-specifications                2023.12.1
# jupyter_client                           7.4.9
# jupyter-console                          6.6.3
# jupyter_core                             5.7.2
# jupyter-events                           0.10.0
# jupyter-http-over-ws                     0.0.8
# jupyter-lsp                              1.5.1
# jupyter_server                           2.12.5
# jupyter_server_fileid                    0.9.2
# jupyter-server-mathjax                   0.2.6
# jupyter_server_proxy                     4.2.0
# jupyter_server_terminals                 0.5.3
# jupyter_server_ydoc                      0.8.0
# jupyter-ydoc                             0.2.5
# jupyterlab                               4.3.1
# jupyterlab_git                           0.44.0
# jupyterlab-lsp                           5.1.0
# jupyterlab_pygments                      0.3.0
# jupyterlab_server                        2.27.2
# jupyterlab_widgets                       3.0.13
# jupytext                                 1.16.2
# kaggle                                   1.6.17
# kaggle-environments                      1.16.9
# kagglehub                                0.3.4
# keras                                    3.3.3
# keras-core                               0.1.7
# keras-cv                                 0.9.0
# keras-hub                                0.17.0
# keras-nlp                                0.17.0
# keras-tuner                              1.4.7
# kernels-mixer                            0.0.13
# keyring                                  25.2.1
# keyrings.google-artifactregistry-auth    1.1.2
# kfp                                      2.5.0
# kfp-pipeline-spec                        0.2.2
# kfp-server-api                           2.0.5
# kiwisolver                               1.4.5
# kornia                                   0.7.4
# kornia_rs                                0.1.7
# kt-legacy                                1.0.5
# kubernetes                               26.1.0
# langcodes                                3.4.1
# langid                                   1.1.6
# language_data                            1.3.0
# lazy_loader                              0.4
# learntools                               0.3.4
# leven                                    1.0.4
# libclang                                 18.1.1
# libmambapy                               1.5.11
# libpysal                                 4.9.2
# librosa                                  0.10.2.post1
# lightgbm                                 4.2.0
# lightning-utilities                      0.11.9
# lime                                     0.2.0.1
# line_profiler                            4.1.3
# linkify-it-py                            2.0.3
# llvmlite                                 0.43.0
# lml                                      0.1.0
# locket                                   1.0.0
# lxml                                     5.3.0
# lz4                                      4.3.3
# Mako                                     1.3.6
# marisa-trie                              1.2.0
# Markdown                                 3.6
# markdown-it-py                           3.0.0
# MarkupSafe                               2.1.5
# marshmallow                              3.23.1
# matplotlib                               3.7.5
# matplotlib-inline                        0.1.7
# matplotlib-venn                          1.1.1
# mccabe                                   0.7.0
# mdit-py-plugins                          0.4.1
# mdurl                                    0.1.2
# memory-profiler                          0.61.0
# memray                                   1.12.0
# menuinst                                 2.1.1
# missingno                                0.5.2
# mistune                                  0.8.4
# mizani                                   0.13.0
# ml-dtypes                                0.3.2
# mlcrate                                  0.2.0
# mlxtend                                  0.23.3
# mne                                      1.8.0
# more-itertools                           10.3.0
# mpld3                                    0.5.10
# mpmath                                   1.3.0
# msgpack                                  1.0.8
# multidict                                6.0.5
# multimethod                              1.11.2
# multipledispatch                         1.0.0
# multiprocess                             0.70.16
# munkres                                  1.1.4
# murmurhash                               1.0.10
# mypy-extensions                          1.0.0
# namex                                    0.0.8
# narwhals                                 1.14.2
# nb_conda                                 2.2.1
# nb_conda_kernels                         2.5.1
# nbclassic                                1.1.0
# nbclient                                 0.5.13
# nbconvert                                6.4.5
# nbdev                                    2.3.32
# nbdime                                   3.2.0
# nbformat                                 5.10.4
# ndindex                                  1.9.2
# nest-asyncio                             1.6.0
# networkx                                 3.3
# nibabel                                  5.3.2
# nilearn                                  0.10.4
# ninja                                    1.11.1.2
# nltk                                     3.2.4
# nose                                     1.3.7
# notebook                                 6.5.7
# notebook_executor                        0.2
# notebook_shim                            0.2.4
# numba                                    0.60.0
# numexpr                                  2.10.2
# numpy                                    1.26.4
# nvidia-ml-py                             11.495.46
# nvtx                                     0.2.10
# oauth2client                             4.1.3
# oauthlib                                 3.2.2
# objsize                                  0.6.1
# odfpy                                    1.4.1
# olefile                                  0.47
# onnx                                     1.17.0
# opencensus                               0.11.4
# opencensus-context                       0.1.3
# opencv-contrib-python                    4.10.0.84
# opencv-python                            4.10.0.84
# opencv-python-headless                   4.10.0.84
# openpyxl                                 3.1.5
# openslide-python                         1.4.1
# opentelemetry-api                        1.25.0
# opentelemetry-exporter-otlp              1.25.0
# opentelemetry-exporter-otlp-proto-common 1.25.0
# opentelemetry-exporter-otlp-proto-grpc   1.25.0
# opentelemetry-exporter-otlp-proto-http   1.25.0
# opentelemetry-proto                      1.25.0
# opentelemetry-sdk                        1.25.0
# opentelemetry-semantic-conventions       0.46b0
# opt-einsum                               3.3.0
# optax                                    0.2.2
# optree                                   0.11.0
# optuna                                   4.1.0
# orbax-checkpoint                         0.6.4
# orderly-set                              5.2.2
# orjson                                   3.10.4
# overrides                                7.7.0
# packaging                                21.3
# pandas                                   2.2.3
# pandas-datareader                        0.10.0
# pandas-profiling                         3.6.6
# pandas-summary                           0.2.0
# pandasql                                 0.7.3
# pandocfilters                            1.5.0
# panel                                    1.5.4
# papermill                                2.6.0
# param                                    2.1.1
# parso                                    0.8.4
# parsy                                    2.1
# partd                                    1.4.2
# path                                     17.0.0
# path.py                                  12.5.0
# pathos                                   0.3.3
# patsy                                    0.5.6
# pdf2image                                1.17.0
# pendulum                                 3.0.0
# pettingzoo                               1.24.0
# pexpect                                  4.9.0
# phik                                     0.12.4
# pickleshare                              0.7.5
# pillow                                   10.3.0
# pins                                     0.8.6
# pip                                      24.0
# pkgutil_resolve_name                     1.3.10
# platformdirs                             3.11.0
# plotly                                   5.22.0
# plotly-express                           0.4.1
# plotnine                                 0.14.3
# pluggy                                   1.5.0
# polars                                   1.15.0
# pooch                                    1.8.2
# pox                                      0.3.5
# ppft                                     1.7.6.9
# preprocessing                            0.1.13
# preshed                                  3.0.9
# prettytable                              3.10.0
# prometheus_client                        0.20.0
# promise                                  2.3
# prompt_toolkit                           3.0.47
# prophet                                  1.1.6
# proto-plus                               1.23.0
# protobuf                                 3.20.3
# psutil                                   5.9.3
# ptyprocess                               0.7.0
# pudb                                     2024.1.3
# pure-eval                                0.2.2
# py-cpuinfo                               9.0.0
# py-spy                                   0.3.14
# py4j                                     0.10.9.7
# pyaml                                    24.9.0
# PyArabic                                 0.6.15
# pyarrow                                  17.0.0
# pyarrow-hotfix                           0.6
# pyasn1                                   0.6.0
# pyasn1_modules                           0.4.0
# pybind11                                 2.13.6
# pyclipper                                1.3.0.post6
# pycodestyle                              2.12.1
# pycosat                                  0.6.6
# pycparser                                2.22
# pycryptodome                             3.21.0
# pyct                                     0.5.0
# pycuda                                   2024.1.2
# pydantic                                 2.10.1
# pydantic_core                            2.27.1
# pydata-google-auth                       1.8.2
# pydegensac                               0.1.2
# pydicom                                  3.0.1
# pydocstyle                               6.3.0
# pydot                                    1.4.2
# pydub                                    0.25.1
# pyemd                                    1.0.0
# pyexcel-io                               0.6.7
# pyexcel-ods                              0.6.0
# pyflakes                                 3.2.0
# pygltflib                                1.16.3
# Pygments                                 2.18.0
# PyJWT                                    2.8.0
# pyLDAvis                                 3.4.1
# pylibcudf                                24.10.1
# pylibraft                                24.10.0
# pylint                                   3.3.1
# pymc3                                    3.11.4
# pymongo                                  3.13.0
# Pympler                                  1.1
# pynvjitlink-cu12                         0.4.0
# pynvml                                   11.4.1
# pynvrtc                                  9.2
# pyOpenSSL                                24.0.0
# pyparsing                                3.1.2
# pypdf                                    5.1.0
# pyproj                                   3.6.1
# pyshp                                    2.3.1
# PySocks                                  1.7.1
# pytesseract                              0.3.13
# pytest                                   8.3.3
# python-bidi                              0.6.3
# python-dateutil                          2.9.0.post0
# python-dotenv                            1.0.1
# python-json-logger                       2.0.7
# python-louvain                           0.16
# python-lsp-jsonrpc                       1.1.2
# python-lsp-server                        1.12.0
# python-multipart                         0.0.9
# python-slugify                           8.0.4
# pytoolconfig                             1.3.1
# pytools                                  2024.1.16
# pytorch-ignite                           0.5.1
# pytorch-lightning                        2.4.0
# pytz                                     2024.1
# pyu2f                                    0.1.5
# PyUpSet                                  0.1.1.post7
# pyviz_comms                              3.0.3
# PyWavelets                               1.6.0
# PyYAML                                   6.0.2
# pyzmq                                    26.0.3
# qtconsole                                5.6.1
# QtPy                                     2.4.2
# raft-dask                                24.10.0
# rapids-dask-dependency                   24.10.0a0
# ray                                      2.24.0
# ray-cpp                                  2.24.0
# referencing                              0.35.1
# regex                                    2024.5.15
# requests                                 2.32.3
# requests-oauthlib                        2.0.0
# requests-toolbelt                        0.10.1
# retrying                                 1.3.3
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rgf-python                               3.12.0
# rich                                     13.7.1
# rmm                                      24.10.0
# rope                                     1.13.0
# rpds-py                                  0.18.1
# rsa                                      4.9
# Rtree                                    1.3.0
# ruamel.yaml                              0.18.6
# ruamel.yaml.clib                         0.2.8
# ruamel-yaml-conda                        0.15.100
# s3fs                                     2024.9.0
# s3transfer                               0.6.2
# safetensors                              0.4.5
# scikit-image                             0.23.2
# scikit-learn                             1.2.2
# scikit-learn-intelex                     2025.0.0
# scikit-multilearn                        0.2.0
# scikit-optimize                          0.10.2
# scikit-plot                              0.3.7
# scikit-surprise                          1.1.4
# scipy                                    1.14.1
# seaborn                                  0.12.2
# SecretStorage                            3.3.3
# segment_anything                         1.0
# semver                                   3.0.2
# Send2Trash                               1.8.3
# sentencepiece                            0.2.0
# sentry-sdk                               2.19.0
# setproctitle                             1.3.4
# setuptools                               70.0.0
# setuptools-scm                           8.1.0
# shap                                     0.44.1
# Shapely                                  1.8.5.post1
# shellingham                              1.5.4
# Shimmy                                   1.3.0
# simpervisor                              1.0.0
# simple_parsing                           0.1.5
# SimpleITK                                2.4.0
# simsimd                                  6.2.0
# six                                      1.16.0
# sklearn-pandas                           2.2.0
# slicer                                   0.0.7
# smart-open                               7.0.4
# smmap                                    5.0.1
# sniffio                                  1.3.1
# snowballstemmer                          2.2.0
# sortedcontainers                         2.4.0
# soundfile                                0.12.1
# soupsieve                                2.5
# soxr                                     0.5.0.post1
# spacy                                    3.8.2
# spacy-legacy                             3.0.12
# spacy-loggers                            1.0.5
# sphinx-rtd-theme                         0.2.4
# SQLAlchemy                               2.0.30
# sqlglot                                  19.9.0
# sqlparse                                 0.5.0
# squarify                                 0.4.4
# srsly                                    2.4.8
# stable-baselines3                        2.1.0
# stack-data                               0.6.2
# stanio                                   0.5.1
# starlette                                0.37.2
# statsmodels                              0.14.2
# stopit                                   1.1.2
# stringzilla                              3.10.10
# stumpy                                   1.13.0
# sympy                                    1.13.3
# tables                                   3.10.1
# tabulate                                 0.9.0
# tangled-up-in-unicode                    0.2.0
# tbb                                      2022.0.0
# tblib                                    3.0.0
# tcmlib                                   1.2.0
# tenacity                                 8.3.0
# tensorboard                              2.16.2
# tensorboard-data-server                  0.7.2
# tensorboard_plugin_profile               2.15.1
# tensorboardX                             2.6.2.2
# tensorflow                               2.16.1
# tensorflow-cloud                         0.1.16
# tensorflow-datasets                      4.9.6
# tensorflow_decision_forests              1.9.1
# tensorflow-estimator                     2.15.0
# tensorflow-hub                           0.16.1
# tensorflow-io                            0.37.0
# tensorflow-io-gcs-filesystem             0.37.0
# tensorflow-metadata                      0.14.0
# tensorflow-probability                   0.24.0
# tensorflow-serving-api                   2.16.1
# tensorflow-text                          2.16.1
# tensorflow-transform                     0.14.0
# tensorstore                              0.1.69
# termcolor                                2.4.0
# terminado                                0.18.1
# testpath                                 0.6.0
# text-unidecode                           1.3
# textblob                                 0.18.0.post0
# texttable                                1.7.0
# textual                                  0.67.1
# tf_keras                                 2.16.0
# Theano                                   1.0.5
# Theano-PyMC                              1.1.2
# thinc                                    8.3.2
# threadpoolctl                            3.5.0
# tifffile                                 2024.5.22
# time-machine                             2.14.1
# timm                                     1.0.11
# tinycss2                                 1.3.0
# tokenizers                               0.20.3
# toml                                     0.10.2
# tomli                                    2.0.1
# tomlkit                                  0.13.2
# toolz                                    0.12.1
# torch                                    2.4.0
# torchaudio                               2.4.0
# torchinfo                                1.8.0
# torchmetrics                             1.6.0
# torchvision                              0.19.0
# tornado                                  6.4.1
# TPOT                                     0.12.1
# tqdm                                     4.66.4
# traceml                                  1.0.8
# traitlets                                5.14.3
# traittypes                               0.2.1
# transformers                             4.46.3
# treelite                                 4.3.0
# truststore                               0.8.0
# trx-python                               0.3
# tsfresh                                  0.20.3
# typeguard                                4.3.0
# typer                                    0.12.3
# typer-slim                               0.13.1
# types-python-dateutil                    2.9.0.20240316
# typing_extensions                        4.12.2
# typing-inspect                           0.9.0
# typing-utils                             0.1.0
# tzdata                                   2024.1
# uc-micro-py                              1.0.3
# ucx-py                                   0.40.0
# ucxx                                     0.40.0
# ujson                                    5.10.0
# unicodedata2                             15.1.0
# update-checker                           0.18.0
# uri-template                             1.3.0
# uritemplate                              3.0.1
# urllib3                                  1.26.18
# urwid                                    2.6.16
# urwid_readline                           0.15.1
# uvicorn                                  0.30.1
# uvloop                                   0.19.0
# virtualenv                               20.21.0
# visions                                  0.7.5
# vtk                                      9.4.0
# Wand                                     0.6.13
# wandb                                    0.18.7
# wasabi                                   1.1.2
# watchdog                                 6.0.0
# watchfiles                               0.22.0
# wavio                                    0.0.9
# wcwidth                                  0.2.13
# weasel                                   0.4.1
# webcolors                                24.6.0
# webencodings                             0.5.1
# websocket-client                         1.8.0
# websockets                               12.0
# Werkzeug                                 3.1.3
# whatthepatch                             1.0.7
# wheel                                    0.43.0
# widgetsnbextension                       4.0.13
# witwidget                                1.8.1
# woodwork                                 0.31.0
# wordcloud                                1.9.3
# wrapt                                    1.16.0
# wurlitzer                                3.1.1
# xarray                                   2024.11.0
# xarray-einstats                          0.8.0
# xgboost                                  2.0.3
# xvfbwrapper                              0.2.9
# xxhash                                   3.4.1
# xyzservices                              2024.9.0
# y-py                                     0.6.2
# yapf                                     0.43.0
# yarl                                     1.9.4
# ydata-profiling                          4.12.0
# ydf                                      0.8.0
# yellowbrick                              1.5
# ypy-websocket                            0.8.4
# zict                                     3.0.0
# zipp                                     3.19.2
# zstandard                                0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras import layers

frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))  # Input shape for the sequence data
mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")  # Input mask

# Convolutional layers to process the frame features
x = layers.Conv1D(32, 3, activation="relu", padding="same")(frame_features_input)  # 1D Conv Layer
x = layers.MaxPooling1D(2)(x)  # MaxPooling layer to downsample
x = layers.Conv1D(64, 3, activation="relu", padding="same")(x)  # Another Conv Layer
x = layers.MaxPooling1D(2)(x)  # MaxPooling layer to downsample
x = layers.Conv1D(128, 3, activation="relu", padding="same")(x)  # Another Conv Layer
x = layers.MaxPooling1D(2)(x)  # MaxPooling layer to downsample

# Flatten the output of the Conv layers
x = layers.Flatten()(x)

# Dropout layer for regularization
x = layers.Dropout(0.4)(x)

# Dense layer for final representation
x = layers.Dense(128, activation="relu")(x)

# Output layer for classification (3 classes)
output = layers.Dense(3, activation="softmax")(x)

# Define the model
model = keras.Model([frame_features_input, mask_input], output)

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Summary of the model architecture
model.summary()
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10      │ (None, 20, 2048)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 20, 32)    │    196,640 │ input_layer_10[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_8     │ (None, 10, 32)    │          0 │ conv1d_8[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 10, 64)    │      6,208 │ max_pooling1d_8[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_9     │ (None, 5, 64)     │          0 │ conv1d_9[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 5, 128)    │     24,704 │ max_pooling1d_9[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_10    │ (None, 2, 128)    │          0 │ conv1d_10[0][0]   │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 256)       │          0 │ max_pooling1d_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 256)       │          0 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 128)       │     32,896 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_11      │ (None, 20)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 3)         │        387 │ dense_8[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 260,835 (1018.89 KB)
#  Trainable params: 260,835 (1018.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Convert labels to one-hot encoding
from tensorflow.keras.utils import to_categorical
train_labels_one_hot = to_categorical(train_labels, num_classes=3)
test_labels_one_hot = to_categorical(test_labels, num_classes=3)

# Fit the model
checkpoint = keras.callbacks.ModelCheckpoint('./cnn_best_weights.weights.h5', 
                                              save_weights_only=True, 
                                              save_best_only=True)

history = model.fit(
    [train_data[0], train_data[1]],  # Frame features and masks
    train_labels_one_hot,  # One-hot encoded labels
    validation_data=([test_data[0], test_data[1]], test_labels_one_hot),  # One-hot encoded validation labels
    callbacks=[checkpoint],
    epochs=200,
    batch_size=8
)
# Out:
# Epoch 1/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.3687 - loss: 1.1451 - val_accuracy: 0.3993 - val_loss: 1.0672
# Epoch 2/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4365 - loss: 1.0487 - val_accuracy: 0.3918 - val_loss: 1.0692
# Epoch 3/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4224 - loss: 1.0499 - val_accuracy: 0.4291 - val_loss: 1.0233
# Epoch 4/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4369 - loss: 1.0305 - val_accuracy: 0.4254 - val_loss: 1.0345
# Epoch 5/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4768 - loss: 0.9853 - val_accuracy: 0.4739 - val_loss: 0.9619
# Epoch 6/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4761 - loss: 0.9601 - val_accuracy: 0.4813 - val_loss: 0.9480
# Epoch 7/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5071 - loss: 0.9318 - val_accuracy: 0.4627 - val_loss: 0.9566
# Epoch 8/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4986 - loss: 0.9352 - val_accuracy: 0.5112 - val_loss: 0.9281
# Epoch 9/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5194 - loss: 0.9022 - val_accuracy: 0.5112 - val_loss: 0.9089
# Epoch 10/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5403 - loss: 0.8670 - val_accuracy: 0.5149 - val_loss: 0.9004
# Epoch 11/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5290 - loss: 0.8972 - val_accuracy: 0.5187 - val_loss: 0.9140
# Epoch 12/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3582 - loss: 1.0987 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 76/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3547 - loss: 1.0981 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 77/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3590 - loss: 1.0971 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 78/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3515 - loss: 1.0981 - val_accuracy: 0.3619 - val_loss: 1.0967
# Epoch 79/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3672 - loss: 1.0967 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 80/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3699 - loss: 1.0972 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 81/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3583 - loss: 1.0979 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 82/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3563 - loss: 1.0982 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 83/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3602 - loss: 1.0973 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 84/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3598 - loss: 1.0975 - val_accuracy: 0.3619 - val_loss: 1.0968
# Epoch 85/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3654 - loss: 1.0966 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 86/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3684 - loss: 1.0965 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 87/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3644 - loss: 1.0970 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 88/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3665 - loss: 1.0964 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 89/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3695 - loss: 1.0966 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 90/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3550 - loss: 1.0978 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 91/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3573 - loss: 1.0974 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 92/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3551 - loss: 1.0979 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 93/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3610 - loss: 1.0968 - val_accuracy: 0.3619 - val_loss: 1.0967
# Epoch 94/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3508 - loss: 1.0981 - val_accuracy: 0.3619 - val_loss: 1.0967
# Epoch 95/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3594 - loss: 1.0976 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 96/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3586 - loss: 1.0967 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 97/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3701 - loss: 1.0957 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 98/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3586 - loss: 1.0980 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 99/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3515 - loss: 1.0983 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 100/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3742 - loss: 1.0958 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 101/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3611 - loss: 1.0965 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 102/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3651 - loss: 1.0969 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 103/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3551 - loss: 1.0977 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 104/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3541 - loss: 1.0980 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 105/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3812 - loss: 1.0937 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 106/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3607 - loss: 1.0968 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 107/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3671 - loss: 1.0964 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 108/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3686 - loss: 1.0964 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 109/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3586 - loss: 1.0973 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 110/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3818 - loss: 1.0948 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 111/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3468 - loss: 1.0982 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 112/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3614 - loss: 1.0971 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 113/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3390 - loss: 1.1000 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 114/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3487 - loss: 1.0988 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 115/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3576 - loss: 1.0968 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 116/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3683 - loss: 1.0957 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 117/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3519 - loss: 1.0978 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 118/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3769 - loss: 1.0949 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 119/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3559 - loss: 1.0979 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 120/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3634 - loss: 1.0965 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 121/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3821 - loss: 1.0940 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 122/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3840 - loss: 1.0933 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 123/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3637 - loss: 1.0974 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 124/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3559 - loss: 1.0979 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 125/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3610 - loss: 1.0977 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 126/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3512 - loss: 1.0990 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 127/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3670 - loss: 1.0963 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 128/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3658 - loss: 1.0959 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 129/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3649 - loss: 1.0963 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 130/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3613 - loss: 1.0969 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 131/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3735 - loss: 1.0949 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 132/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3560 - loss: 1.0971 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 133/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3759 - loss: 1.0951 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 134/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3643 - loss: 1.0962 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 135/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3713 - loss: 1.0949 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 136/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3541 - loss: 1.0982 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 137/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3616 - loss: 1.0973 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 138/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3600 - loss: 1.0967 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 139/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3473 - loss: 1.0990 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 140/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3705 - loss: 1.0954 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 141/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3618 - loss: 1.0976 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 142/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3546 - loss: 1.0974 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 143/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3700 - loss: 1.0962 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 144/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3616 - loss: 1.0973 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 145/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3600 - loss: 1.0962 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 146/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3663 - loss: 1.0966 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 147/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3612 - loss: 1.0970 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 148/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3721 - loss: 1.0952 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 149/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3595 - loss: 1.0970 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 150/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3447 - loss: 1.0985 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 151/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3527 - loss: 1.0982 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 152/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3605 - loss: 1.0975 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 153/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3532 - loss: 1.0982 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 154/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3714 - loss: 1.0958 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 155/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3525 - loss: 1.0974 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 156/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3555 - loss: 1.0982 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 157/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3607 - loss: 1.0969 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 158/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3601 - loss: 1.0972 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 159/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3610 - loss: 1.0966 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 160/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3678 - loss: 1.0958 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 161/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3511 - loss: 1.0982 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 162/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3536 - loss: 1.0981 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 163/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3706 - loss: 1.0955 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 164/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3748 - loss: 1.0949 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 165/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3619 - loss: 1.0966 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 166/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3588 - loss: 1.0970 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 167/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3611 - loss: 1.0973 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 168/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3572 - loss: 1.0970 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 169/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3746 - loss: 1.0950 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 170/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3785 - loss: 1.0947 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 171/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3723 - loss: 1.0951 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 172/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3603 - loss: 1.0969 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 173/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3484 - loss: 1.0982 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 174/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3723 - loss: 1.0955 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 175/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3685 - loss: 1.0965 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 176/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3618 - loss: 1.0961 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 177/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3561 - loss: 1.0970 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 178/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3603 - loss: 1.0969 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 179/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3811 - loss: 1.0946 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 180/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3606 - loss: 1.0966 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 181/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3457 - loss: 1.0977 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 182/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3745 - loss: 1.0947 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 183/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3448 - loss: 1.0989 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 184/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3799 - loss: 1.0944 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 185/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3565 - loss: 1.0981 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 186/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3697 - loss: 1.0957 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 187/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3648 - loss: 1.0963 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 188/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3632 - loss: 1.0969 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 189/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3599 - loss: 1.0967 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 190/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3770 - loss: 1.0953 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 191/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3712 - loss: 1.0948 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 192/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3621 - loss: 1.0967 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 193/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3564 - loss: 1.0975 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 194/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3653 - loss: 1.0965 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 195/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3578 - loss: 1.0969 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 196/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3747 - loss: 1.0954 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 197/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3653 - loss: 1.0969 - val_accuracy: 0.3619 - val_loss: 1.0965
# Epoch 198/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3446 - loss: 1.0987 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 199/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3447 - loss: 1.0992 - val_accuracy: 0.3619 - val_loss: 1.0966
# Epoch 200/200
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3827 - loss: 1.0941 - val_accuracy: 0.3619 - val_loss: 1.0965

# %%
import matplotlib.pyplot as plt

# Extract the history of accuracy and loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Plot training & validation loss values
plt.figure(figsize=(12, 6))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy Plot
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Train Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Predict the labels for the test data
y_pred = model.predict([test_data[0], test_data[1]])
y_pred_classes = np.argmax(y_pred, axis=1)  # Get the index of the max probability for each prediction
y_true = np.argmax(test_labels_one_hot, axis=1)  # Get the true labels from one-hot encoding

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Plot Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Normal', 'Violence', 'Weaponized'], 
            yticklabels=['Normal', 'Violence', 'Weaponized'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Classification Report
cr = classification_report(y_true, y_pred_classes, target_names=['Normal', 'Violence', 'Weaponized'])
print("Classification Report:\n", cr)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.00      0.00      0.00        88
#     Violence       0.36      1.00      0.53        97
#   Weaponized       0.00      0.00      0.00        83
#
#     accuracy                           0.36       268
#    macro avg       0.12      0.33      0.18       268
# weighted avg       0.13      0.36      0.19       268
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Save the entire model (architecture, weights, optimizer)
model.save('CNN.h5')

# %%
from keras.models import load_model
model = load_model('CNN.h5')

# %%
import keras
import cv2
import numpy as np
from keras.models import load_model

# Define constants
IMG_SIZE = 224  # Image size for InceptionV3
MAX_SEQ_LENGTH = 20  # Adjusted to match model's expected sequence length
NUM_FEATURES = 2048  # Features from InceptionV3 (features per frame)

# Load the model
model = load_model('GRU.h5')

# Function to load and preprocess a single video
def load_single_video(path, max_frames=MAX_SEQ_LENGTH, resize=(IMG_SIZE, IMG_SIZE)):
    cap = cv2.VideoCapture(path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = crop_center_square(frame)
            frame = cv2.resize(frame, resize)
            frame = frame[:, :, [2, 1, 0]]  # Convert from BGR to RGB
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
    return np.array(frames)

# Crop the center square of the frame
def crop_center_square(frame):
    y, x = frame.shape[0:2]
    min_dim = min(y, x)
    start_x = (x // 2) - (min_dim // 2)
    start_y = (y // 2) - (min_dim // 2)
    return frame[start_y:start_y + min_dim, start_x:start_x + min_dim]

# Preprocess the frames (extract features using InceptionV3)
def preprocess_frames(frames):
    feature_extractor = keras.applications.InceptionV3(
        weights="imagenet", include_top=False, pooling="avg", input_shape=(IMG_SIZE, IMG_SIZE, 3)
    )
    preprocess_input = keras.applications.inception_v3.preprocess_input

    frames = preprocess_input(frames)  # Preprocess the frames
    features = feature_extractor.predict(frames)
    return features

# Load and preprocess the video
video_path = '/kaggle/input/smartcity-cctv-violence-detection-dataset-scvd/SCVD/SCVD_converted/Test/Normal/t_n010_converted.avi'  # Replace with your video path
frames = load_single_video(video_path)
features = preprocess_frames(frames)

# Limit the number of frames to 20 (if necessary)
features = features[:MAX_SEQ_LENGTH]  # Shape: (20, 2048)
features = features[None, :, :]  # Shape: (1, 20, 2048) (batch_size, sequence_length, num_features)
mask = np.ones((1, len(features[0])))  # Mask for all frames (1 = not masked)

# Predict the label
prediction = model.predict([features, mask])

# Print the predicted class
class_labels = ['Normal', 'Violence', 'Weaponized']
predicted_class = class_labels[np.argmax(prediction)]
print(f"Predicted class: {predicted_class}")
